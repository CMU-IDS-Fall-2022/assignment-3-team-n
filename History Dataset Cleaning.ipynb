# %%
# From movies_class_demo file from class
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json, ast
import mpl_toolkits

sns.set()
# %matplotlib inline

# %%
df0 = pd.read_csv("WC22_main.csv", encoding = "latin1")
df = pd.read_csv("World Cup Match History.csv", encoding = "latin1")

# %%
teams = df0["Team"].unique()

# %%
df.describe(include = 'all')
# Out:
#                Year              Datetime        Stage         Stadium  \
# count    852.000000                   852          852             852
# unique          NaN                   602           23             181
# top             NaN  27 May 1934 - 16:30   Round of 16  Estadio Azteca
# freq            NaN                     8           72              19
# mean    1985.089202                   NaN          NaN             NaN
# std       22.448825                   NaN          NaN             NaN
# min     1930.000000                   NaN          NaN             NaN
# 25%     1970.000000                   NaN          NaN             NaN
# 50%     1990.000000                   NaN          NaN             NaN
# 75%     2002.000000                   NaN          NaN             NaN
# max     2014.000000                   NaN          NaN             NaN
#
#                 City Home Team Name  Home Team Goals  Away Team Goals  \
# ...

# %%
df.dropna()
# Out:
#        Year              Datetime                     Stage  \
# 0    1930.0  13 Jul 1930 - 15:00                    Group 1
# 1    1930.0  13 Jul 1930 - 15:00                    Group 4
# 2    1930.0  14 Jul 1930 - 12:45                    Group 2
# 3    1930.0  14 Jul 1930 - 14:50                    Group 3
# 4    1930.0  15 Jul 1930 - 16:00                    Group 1
# ..      ...                   ...                       ...
# 847  2014.0  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014.0  08 Jul 2014 - 17:00                Semi-finals
# 849  2014.0  09 Jul 2014 - 17:00                Semi-finals
# 850  2014.0  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014.0  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 0                Pocitos      Montevideo          France              4.0
# 1         Parque Central      Montevideo             USA              3.0
# ...

# %%
df['Home Team Name'].unique()
# Out:
# array(['France', 'USA', 'Yugoslavia', 'Romania', 'Argentina', 'Chile',
#        'Uruguay', 'Brazil', 'Paraguay', 'Austria', 'Hungary',
#        'Switzerland', 'Sweden', 'Germany', 'Spain', 'Italy',
#        'Czechoslovakia', 'Cuba', 'England', 'Germany FR', 'Turkey',
#        'Soviet Union', 'Northern Ireland', 'Mexico', 'Wales', 'Portugal',
#        'Korea DPR', 'Peru', 'Belgium', 'Bulgaria', 'German DR', 'Zaire',
#        'Poland', 'Australia', 'Scotland', 'Netherlands', 'Haiti',
#        'Tunisia', 'Algeria', 'Honduras', 'Canada', 'Morocco',
#        'Korea Republic', 'Iraq', 'Denmark', 'rn">United Arab Emirates',
#        'Costa Rica', 'Cameroon', 'rn">Republic of Ireland', 'Colombia',
#        'Norway', 'Nigeria', 'Saudi Arabia', 'Bolivia', 'Russia', 'Greece',
#        'Jamaica', 'South Africa', 'Japan', 'Croatia', 'China PR',
#        'Senegal', 'Slovenia', 'Ecuador', 'rn">Trinidad and Tobago',
#        'rn">Serbia and Montenegro', 'Angola', 'Czech Republic', 'Togo',
# ...

# %%
df = df.replace({'Home Team Name': {'Germany FR': 'Germany'}})
df = df.replace({'Home Team Name': {'Germany DR': 'Germany'}})
df = df.replace({'Home Team Name': {'Korea Republic': 'South Korea'}})
df = df.replace({'Home Team Name': {'IR Iran': 'Iran'}})
df = df.replace({'Away Team Name': {'Germany FR': 'Germany'}})
df = df.replace({'Away Team Name': {'Germany DR': 'Germany'}})
df = df.replace({'Away Team Name': {'Korea Republic': 'South Korea'}})
df = df.replace({'Away Team Name': {'IR Iran': 'Iran'}})

# %% [markdown]
# #### Removing Rows where the current WC teams haven't played

# %%
df.loc[(df['Home Team Name'].isin(teams)) | (df['Away Team Name'].isin(teams))]
# Out:
#        Year              Datetime                     Stage  \
# 0    1930.0  13 Jul 1930 - 15:00                    Group 1
# 1    1930.0  13 Jul 1930 - 15:00                    Group 4
# 2    1930.0  14 Jul 1930 - 12:45                    Group 2
# 4    1930.0  15 Jul 1930 - 16:00                    Group 1
# 5    1930.0  16 Jul 1930 - 14:45                    Group 1
# ..      ...                   ...                       ...
# 847  2014.0  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014.0  08 Jul 2014 - 17:00                Semi-finals
# 849  2014.0  09 Jul 2014 - 17:00                Semi-finals
# 850  2014.0  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014.0  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 0                Pocitos      Montevideo          France              4.0
# 1         Parque Central      Montevideo             USA              3.0
# ...

# %%
df = df[['Year', 'Stage', 'Home Team Name', 'Home Team Goals', 'Away Team Name', 'Away Team Goals']]

# %%
df.loc[df['Year'] == 1930]
# Out:
#       Year        Stage Home Team Name  Home Team Goals Away Team Name  \
# 0   1930.0      Group 1         France              4.0         Mexico
# 1   1930.0      Group 4            USA              3.0        Belgium
# 2   1930.0      Group 2     Yugoslavia              2.0         Brazil
# 3   1930.0      Group 3        Romania              3.0           Peru
# 4   1930.0      Group 1      Argentina              1.0         France
# 5   1930.0      Group 1          Chile              3.0         Mexico
# 6   1930.0      Group 2     Yugoslavia              4.0        Bolivia
# 7   1930.0      Group 4            USA              3.0       Paraguay
# 8   1930.0      Group 3        Uruguay              1.0           Peru
# 9   1930.0      Group 1          Chile              1.0         France
# 10  1930.0      Group 1      Argentina              6.0         Mexico
# 11  1930.0      Group 2         Brazil              4.0        Bolivia
# ...

# %%
df.dtypes.to_dict()
# Out:
# {'Year': dtype('float64'),
#  'Stage': dtype('O'),
#  'Home Team Name': dtype('O'),
#  'Home Team Goals': dtype('float64'),
#  'Away Team Name': dtype('O'),
#  'Away Team Goals': dtype('float64')}

# %%
df = df.fillna(0)
df = df.astype({
    "Year" : int,
    "Stage" : str,
    "Home Team Name" : str,
    "Home Team Goals" : int,
    "Away Team Name" : str,
    "Away Team Goals" : int
})

# %%
df.dtypes.to_dict()
# Out:
# {'Year': dtype('int32'),
#  'Stage': dtype('O'),
#  'Home Team Name': dtype('O'),
#  'Home Team Goals': dtype('int32'),
#  'Away Team Name': dtype('O'),
#  'Away Team Goals': dtype('int32')}

# %%
df.to_csv('History.csv', index = False)
